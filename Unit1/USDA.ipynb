# %%
pwd()
# Out:
# 'C:\\Users\\Dennis\\OneDrive\\Documents\\MITx 15.071x\\Unit1'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("USDA.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7058 entries, 0 to 7057
# Data columns (total 16 columns):
# ID              7058 non-null int64
# Description     7058 non-null object
# Calories        7057 non-null float64
# Protein         7057 non-null float64
# TotalFat        7057 non-null float64
# Carbohydrate    7057 non-null float64
# Sodium          6974 non-null float64
# SaturatedFat    6757 non-null float64
# Cholesterol     6770 non-null float64
# Sugar           5148 non-null float64
# Calcium         6922 non-null float64
# Iron            6935 non-null float64
# Potassium       6649 non-null float64
# VitaminC        6726 non-null float64
# VitaminE        4338 non-null float64
# VitaminD        4224 non-null float64
# dtypes: float64(14), int64(1), object(1)
# memory usage: 882.3+ KB

# %%
df.describe()
# Out:
#                  ID     Calories      Protein     TotalFat  Carbohydrate  \
# count   7058.000000  7057.000000  7057.000000  7057.000000   7057.000000
# mean   14259.821196   219.695338    11.710368    10.320614     20.697860
# std     8577.179705   172.198755    10.919356    16.814191     27.630443
# min     1001.000000     0.000000     0.000000     0.000000      0.000000
# 25%     8387.250000    85.000000     2.290000     0.720000      0.000000
# 50%    13293.500000   181.000000     8.200000     4.370000      7.130000
# 75%    18336.750000   331.000000    20.430000    12.700000     28.170000
# max    93600.000000   902.000000    88.320000   100.000000    100.000000
#
#              Sodium  SaturatedFat  Cholesterol        Sugar      Calcium  \
# count   6974.000000   6757.000000  6770.000000  5148.000000  6922.000000
# mean     322.059220      3.452267    41.551994     8.256540    73.530627
# std     1045.416931      6.921267   122.963028    15.361509   222.445338
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Description', 'Calories', 'Protein', 'TotalFat', 'Carbohydrate',
#        'Sodium', 'SaturatedFat', 'Cholesterol', 'Sugar', 'Calcium', 'Iron',
#        'Potassium', 'VitaminC', 'VitaminE', 'VitaminD'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7058, step=1)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df)
# Out:
# 7058

# %%
round(df,0)
# Out:
#          ID                                        Description  Calories  \
# 0      1001                                   BUTTER,WITH SALT     717.0
# 1      1002                           BUTTER,WHIPPED,WITH SALT     717.0
# 2      1003                               BUTTER OIL,ANHYDROUS     876.0
# 3      1004                                        CHEESE,BLUE     353.0
# 4      1005                                       CHEESE,BRICK     371.0
# 5      1006                                        CHEESE,BRIE     334.0
# 6      1007                                   CHEESE,CAMEMBERT     300.0
# 7      1008                                     CHEESE,CARAWAY     376.0
# 8      1009                                     CHEESE,CHEDDAR     403.0
# 9      1010                                    CHEESE,CHESHIRE     387.0
# 10     1011                                       CHEESE,COLBY     394.0
# 11     1012                CHEESE,COTTAGE,CRMD,LRG OR SML CURD      98.0
# ...

# %%
min(df)
# Out:
# 'Calcium'

# %%
df.shape
# Out:
# (7058, 16)

# %%
df.size
# Out:
# 112928

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7058, step=1)

# %%
df.columns
# Out:
# Index(['ID', 'Description', 'Calories', 'Protein', 'TotalFat', 'Carbohydrate',
#        'Sodium', 'SaturatedFat', 'Cholesterol', 'Sugar', 'Calcium', 'Iron',
#        'Potassium', 'VitaminC', 'VitaminE', 'VitaminD'],
#       dtype='object')

# %%
df.head()
# Out:
#      ID               Description  Calories  Protein  TotalFat  Carbohydrate  \
# 0  1001          BUTTER,WITH SALT     717.0     0.85     81.11          0.06
# 1  1002  BUTTER,WHIPPED,WITH SALT     717.0     0.85     81.11          0.06
# 2  1003      BUTTER OIL,ANHYDROUS     876.0     0.28     99.48          0.00
# 3  1004               CHEESE,BLUE     353.0    21.40     28.74          2.34
# 4  1005              CHEESE,BRICK     371.0    23.24     29.68          2.79
#
#    Sodium  SaturatedFat  Cholesterol  Sugar  Calcium  Iron  Potassium  \
# 0   714.0        51.368        215.0   0.06     24.0  0.02       24.0
# 1   827.0        50.489        219.0   0.06     24.0  0.16       26.0
# 2     2.0        61.924        256.0   0.00      4.0  0.00        5.0
# 3  1395.0        18.669         75.0   0.50    528.0  0.31      256.0
# 4   560.0        18.764         94.0   0.51    674.0  0.43      136.0
#
#    VitaminC  VitaminE  VitaminD
# 0       0.0      2.32       1.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7058 entries, 0 to 7057
# Data columns (total 16 columns):
# ID              7058 non-null int64
# Description     7058 non-null object
# Calories        7057 non-null float64
# Protein         7057 non-null float64
# TotalFat        7057 non-null float64
# Carbohydrate    7057 non-null float64
# Sodium          6974 non-null float64
# SaturatedFat    6757 non-null float64
# Cholesterol     6770 non-null float64
# Sugar           5148 non-null float64
# Calcium         6922 non-null float64
# Iron            6935 non-null float64
# Potassium       6649 non-null float64
# VitaminC        6726 non-null float64
# VitaminE        4338 non-null float64
# VitaminD        4224 non-null float64
# dtypes: float64(14), int64(1), object(1)
# memory usage: 882.3+ KB

# %%
df.min()
# Out:
# ID                                   1001
# Description     ABALONE,MIXED SPECIES,RAW
# Calories                                0
# Protein                                 0
# TotalFat                                0
# Carbohydrate                            0
# Sodium                                  0
# SaturatedFat                            0
# Cholesterol                             0
# Sugar                                   0
# Calcium                                 0
# Iron                                    0
# Potassium                               0
# VitaminC                                0
# VitaminE                                0
# VitaminD                                0
# dtype: object

# %%
df["Sodium"]
# Out:
# 0        714.0
# 1        827.0
# 2          2.0
# 3       1395.0
# 4        560.0
# 5        629.0
# 6        842.0
# 7        690.0
# 8        621.0
# 9        700.0
# 10       604.0
# 11       364.0
# 12       344.0
# 13       330.0
# 14       330.0
# 15       406.0
# 16       321.0
# 17       965.0
# 18      1116.0
# 19       800.0
# 20       600.0
# 21       819.0
# 22       336.0
# 23       800.0
# 24       536.0
# 25       627.0
# 26       415.0
# 27       619.0
# 28       652.0
# 29       628.0
#          ...
# 7028      10.0
# 7029      95.0
# 7030      57.0
# 7031      55.0
# 7032     856.0
# 7033     499.0
# 7034     490.0
# 7035      35.0
# 7036     260.0
# 7037     167.0
# 7038      16.0
# 7039     486.0
# 7040     711.0
# 7041       0.0
# 7042       2.0
# 7043    1297.0
# 7044    1435.0
# 7045    2838.0
# 7046       2.0
# 7047      12.0
# 7048       0.0
# 7049    3326.0
# 7050    1765.0
# 7051    4250.0
# 7052      29.0
# 7053      58.0
# 7054    4450.0
# ...

# %%
type(df["Sodium"])
# Out:
# pandas.core.series.Series

# %%
df[["Sodium"]]
# Out:
#       Sodium
# 0      714.0
# 1      827.0
# 2        2.0
# 3     1395.0
# 4      560.0
# 5      629.0
# 6      842.0
# 7      690.0
# 8      621.0
# 9      700.0
# 10     604.0
# 11     364.0
# 12     344.0
# 13     330.0
# 14     330.0
# 15     406.0
# 16     321.0
# 17     965.0
# 18    1116.0
# 19     800.0
# 20     600.0
# 21     819.0
# 22     336.0
# 23     800.0
# 24     536.0
# 25     627.0
# 26     415.0
# 27     619.0
# 28     652.0
# 29     628.0
# ...      ...
# 7028    10.0
# 7029    95.0
# 7030    57.0
# 7031    55.0
# 7032   856.0
# 7033   499.0
# 7034   490.0
# 7035    35.0
# 7036   260.0
# 7037   167.0
# 7038    16.0
# 7039   486.0
# 7040   711.0
# 7041     0.0
# 7042     2.0
# 7043  1297.0
# 7044  1435.0
# 7045  2838.0
# 7046     2.0
# 7047    12.0
# 7048     0.0
# 7049  3326.0
# 7050  1765.0
# 7051  4250.0
# 7052    29.0
# 7053    58.0
# 7054  4450.0
# 7055   667.0
# 7056    70.0
# 7057    68.0
#
# [7058 rows x 1 columns]

# %%
type(df[["Sodium"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df[["Sodium","Sugar"]]
# Out:
#       Sodium  Sugar
# 0      714.0   0.06
# 1      827.0   0.06
# 2        2.0   0.00
# 3     1395.0   0.50
# 4      560.0   0.51
# 5      629.0   0.45
# 6      842.0   0.46
# 7      690.0    NaN
# 8      621.0   0.52
# 9      700.0    NaN
# 10     604.0   0.52
# 11     364.0   2.67
# 12     344.0   2.38
# 13     330.0   1.85
# 14     330.0   3.67
# 15     406.0   2.72
# 16     321.0   3.21
# 17     965.0   1.43
# 18    1116.0   4.09
# 19     800.0   1.55
# 20     600.0    NaN
# 21     819.0   2.22
# 22     336.0   0.36
# 23     800.0   0.49
# 24     536.0   0.50
# 25     627.0   1.03
# 26     415.0   1.01
# 27     619.0   1.13
# 28     652.0   0.60
# 29     628.0   1.12
# ...      ...    ...
# 7028    10.0   1.52
# 7029    95.0  19.88
# 7030    57.0  17.35
# 7031    55.0   5.30
# 7032   856.0   0.53
# 7033   499.0  20.30
# 7034   490.0   0.54
# 7035    35.0   0.42
# 7036   260.0   1.33
# 7037   167.0  35.10
# 7038    16.0   1.23
# 7039   486.0   0.30
# 7040   711.0   6.40
# ...

# %%
df.Sodium
# Out:
# 0        714.0
# 1        827.0
# 2          2.0
# 3       1395.0
# 4        560.0
# 5        629.0
# 6        842.0
# 7        690.0
# 8        621.0
# 9        700.0
# 10       604.0
# 11       364.0
# 12       344.0
# 13       330.0
# 14       330.0
# 15       406.0
# 16       321.0
# 17       965.0
# 18      1116.0
# 19       800.0
# 20       600.0
# 21       819.0
# 22       336.0
# 23       800.0
# 24       536.0
# 25       627.0
# 26       415.0
# 27       619.0
# 28       652.0
# 29       628.0
#          ...
# 7028      10.0
# 7029      95.0
# 7030      57.0
# 7031      55.0
# 7032     856.0
# 7033     499.0
# 7034     490.0
# 7035      35.0
# 7036     260.0
# 7037     167.0
# 7038      16.0
# 7039     486.0
# 7040     711.0
# 7041       0.0
# 7042       2.0
# 7043    1297.0
# 7044    1435.0
# 7045    2838.0
# 7046       2.0
# 7047      12.0
# 7048       0.0
# 7049    3326.0
# 7050    1765.0
# 7051    4250.0
# 7052      29.0
# 7053      58.0
# 7054    4450.0
# ...

# %%
df.Sodium.equals(df["Sodium"])
# Out:
# True

# %%
df.iloc[0]
# Out:
# ID                          1001
# Description     BUTTER,WITH SALT
# Calories                     717
# Protein                     0.85
# TotalFat                   81.11
# Carbohydrate                0.06
# Sodium                       714
# SaturatedFat              51.368
# Cholesterol                  215
# Sugar                       0.06
# Calcium                       24
# Iron                        0.02
# Potassium                     24
# VitaminC                       0
# VitaminE                    2.32
# VitaminD                     1.5
# Name: 0, dtype: object

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
df.iloc[-1]
# Out:
# ID                         93600
# Description     TURTLE,GREEN,RAW
# Calories                      89
# Protein                     19.8
# TotalFat                     0.5
# Carbohydrate                   0
# Sodium                        68
# SaturatedFat               0.127
# Cholesterol                   50
# Sugar                          0
# Calcium                      118
# Iron                         1.4
# Potassium                    230
# VitaminC                       0
# VitaminE                     0.5
# VitaminD                       0
# Name: 7057, dtype: object

# %%
df.iloc[:5]
# Out:
#      ID               Description  Calories  Protein  TotalFat  Carbohydrate  \
# 0  1001          BUTTER,WITH SALT     717.0     0.85     81.11          0.06
# 1  1002  BUTTER,WHIPPED,WITH SALT     717.0     0.85     81.11          0.06
# 2  1003      BUTTER OIL,ANHYDROUS     876.0     0.28     99.48          0.00
# 3  1004               CHEESE,BLUE     353.0    21.40     28.74          2.34
# 4  1005              CHEESE,BRICK     371.0    23.24     29.68          2.79
#
#    Sodium  SaturatedFat  Cholesterol  Sugar  Calcium  Iron  Potassium  \
# 0   714.0        51.368        215.0   0.06     24.0  0.02       24.0
# 1   827.0        50.489        219.0   0.06     24.0  0.16       26.0
# 2     2.0        61.924        256.0   0.00      4.0  0.00        5.0
# 3  1395.0        18.669         75.0   0.50    528.0  0.31      256.0
# 4   560.0        18.764         94.0   0.51    674.0  0.43      136.0
#
#    VitaminC  VitaminE  VitaminD
# 0       0.0      2.32       1.5
# ...

# %%
df.iloc[-5:]  #last 5 rows
# Out:
#          ID                 Description  Calories  Protein  TotalFat  \
# 7053  80200               FROG LEGS,RAW      73.0    16.40      0.30
# 7054  83110             MACKEREL,SALTED     305.0    18.50     25.10
# 7055  90240  SCALLOP,(BAY&SEA),CKD,STMD     111.0    20.54      0.84
# 7056  90560                   SNAIL,RAW      90.0    16.10      1.40
# 7057  93600            TURTLE,GREEN,RAW      89.0    19.80      0.50
#
#       Carbohydrate  Sodium  SaturatedFat  Cholesterol  Sugar  Calcium  Iron  \
# 7053          0.00    58.0         0.076         50.0    0.0     18.0  1.50
# 7054          0.00  4450.0         7.148         95.0    0.0     66.0  1.40
# 7055          5.41   667.0         0.218         41.0    0.0     10.0  0.58
# 7056          2.00    70.0         0.361         50.0    0.0     10.0  3.50
# 7057          0.00    68.0         0.127         50.0    0.0    118.0  1.40
#
#       Potassium  VitaminC  VitaminE  VitaminD
# 7053      285.0       0.0      1.00       0.2
# ...

# %%
df.iloc[0,6]
# Out:
# 714.0

# %%
df.iloc[0,0:3]
# Out:
# ID                         1001
# Description    BUTTER,WITH SALT
# Calories                    717
# Name: 0, dtype: object

# %%
df.iloc[0,[2,4,6,8]]
# Out:
# Calories         717
# TotalFat       81.11
# Sodium           714
# Cholesterol      215
# Name: 0, dtype: object

# %%
df.iloc[0:5,[2,4,6,8]]
# Out:
#    Calories  TotalFat  Sodium  Cholesterol
# 0     717.0     81.11   714.0        215.0
# 1     717.0     81.11   827.0        219.0
# 2     876.0     99.48     2.0        256.0
# 3     353.0     28.74  1395.0         75.0
# 4     371.0     29.68   560.0         94.0

# %%
df.head()
# Out:
#      ID               Description  Calories  Protein  TotalFat  Carbohydrate  \
# 0  1001          BUTTER,WITH SALT     717.0     0.85     81.11          0.06
# 1  1002  BUTTER,WHIPPED,WITH SALT     717.0     0.85     81.11          0.06
# 2  1003      BUTTER OIL,ANHYDROUS     876.0     0.28     99.48          0.00
# 3  1004               CHEESE,BLUE     353.0    21.40     28.74          2.34
# 4  1005              CHEESE,BRICK     371.0    23.24     29.68          2.79
#
#    Sodium  SaturatedFat  Cholesterol  Sugar  Calcium  Iron  Potassium  \
# 0   714.0        51.368        215.0   0.06     24.0  0.02       24.0
# 1   827.0        50.489        219.0   0.06     24.0  0.16       26.0
# 2     2.0        61.924        256.0   0.00      4.0  0.00        5.0
# 3  1395.0        18.669         75.0   0.50    528.0  0.31      256.0
# 4   560.0        18.764         94.0   0.51    674.0  0.43      136.0
#
#    VitaminC  VitaminE  VitaminD
# 0       0.0      2.32       1.5
# ...

# %%
df1 = pd.read_csv("USDA.csv", index_col="ID")

# %%
df1.head()
# Out:
#                    Description  Calories  Protein  TotalFat  Carbohydrate  \
# ID
# 1001          BUTTER,WITH SALT     717.0     0.85     81.11          0.06
# 1002  BUTTER,WHIPPED,WITH SALT     717.0     0.85     81.11          0.06
# 1003      BUTTER OIL,ANHYDROUS     876.0     0.28     99.48          0.00
# 1004               CHEESE,BLUE     353.0    21.40     28.74          2.34
# 1005              CHEESE,BRICK     371.0    23.24     29.68          2.79
#
#       Sodium  SaturatedFat  Cholesterol  Sugar  Calcium  Iron  Potassium  \
# ID
# 1001   714.0        51.368        215.0   0.06     24.0  0.02       24.0
# 1002   827.0        50.489        219.0   0.06     24.0  0.16       26.0
# 1003     2.0        61.924        256.0   0.00      4.0  0.00        5.0
# 1004  1395.0        18.669         75.0   0.50    528.0  0.31      256.0
# 1005   560.0        18.764         94.0   0.51    674.0  0.43      136.0
#
#       VitaminC  VitaminE  VitaminD
# ID
# ...

# %%
df1.loc[1004]
# Out:
# Description     CHEESE,BLUE
# Calories                353
# Protein                21.4
# TotalFat              28.74
# Carbohydrate           2.34
# Sodium                 1395
# SaturatedFat         18.669
# Cholesterol              75
# Sugar                   0.5
# Calcium                 528
# Iron                   0.31
# Potassium               256
# VitaminC                  0
# VitaminE               0.25
# VitaminD                0.5
# Name: 1004, dtype: object

# %%
df1.loc[:1340]
# Out:
#                                             Description  Calories  Protein  \
# ID
# 1001                                   BUTTER,WITH SALT     717.0     0.85
# 1002                           BUTTER,WHIPPED,WITH SALT     717.0     0.85
# 1003                               BUTTER OIL,ANHYDROUS     876.0     0.28
# 1004                                        CHEESE,BLUE     353.0    21.40
# 1005                                       CHEESE,BRICK     371.0    23.24
# 1006                                        CHEESE,BRIE     334.0    20.75
# 1007                                   CHEESE,CAMEMBERT     300.0    19.80
# 1008                                     CHEESE,CARAWAY     376.0    25.18
# 1009                                     CHEESE,CHEDDAR     403.0    24.90
# 1010                                    CHEESE,CHESHIRE     387.0    23.37
# 1011                                       CHEESE,COLBY     394.0    23.76
# ...

# %%
df1.loc[1200:]
# Out:
#                                              Description  Calories  Protein  \
# ID
# 1200                  REDDI WIP FAT FREE WHIPPED TOPPING     149.0     3.00
# 1202            MILK,CHOC,FLUID,COMM,RED FAT,W/ ADDED CA      78.0     2.99
# 1203               YOGURT,FRUIT,LOFAT,W/LO CAL SWEETENER     105.0     4.86
# 1204                  CHEESE,PARMESAN,DRY GRATED,RED FAT     265.0    20.00
# 1205                                  CREAM SUB,FLAV,LIQ     251.0     0.69
# 1206                                  CREAM SUB,FLAV,PDR     498.0     0.68
# 1208                            CHEESE,PROVOLONE,RED FAT     274.0    24.70
# 1209                        CHEESE,MEXICAN,BLEND,RED FAT     282.0    24.69
# 1210                                  EGG MIX,USDA CMDTY     555.0    35.60
# 1211   MILK,WHL,3.25% MILKFAT,WO/ ADDED VIT A & VITAM...      61.0     3.15
# 1212                    MILK,DRY,WHL,WO/ ADDED VITAMIN D     496.0    26.32
# ...
